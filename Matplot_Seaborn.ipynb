# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.DataFrame(np.random.randn(1000),index = pd.date_range('2020-06-10',periods=1000),columns=['value'])

# %%
df
# Out:
#                value
# 2020-06-10 -0.012385
# 2020-06-11  1.614755
# 2020-06-12  1.361562
# 2020-06-13  2.319181
# 2020-06-14  0.277809
# ...              ...
# 2023-03-02  0.038394
# 2023-03-03  0.062133
# 2023-03-04  0.804599
# 2023-03-05 -0.054263
# 2023-03-06  1.030218
#
# [1000 rows x 1 columns]

# %%
df.plot()

# %%
df['value'] = df['value'].cumsum() #cumulative sum

# %%
df.head(10)
# Out:
#                value
# 2020-06-10 -0.012385
# 2020-06-11  1.602370
# 2020-06-12  2.963931
# 2020-06-13  5.283113
# 2020-06-14  5.560922
# 2020-06-15  4.380230
# 2020-06-16  3.829793
# 2020-06-17  3.573032
# 2020-06-18  3.201127
# 2020-06-19  3.293781

# %%
df.plot()

# %%
df['value'] = df['value'] + 10

# %%
df.plot()

# %%
df.head()
# Out:
#                 value
# 2020-06-10   9.987615
# 2020-06-11  11.602370
# 2020-06-12  12.963931
# 2020-06-13  15.283113
# 2020-06-14  15.560922

# %%
iris = sns.load_dataset('iris') #some built in dataset(flower dataset)

# %%
#3 flowers in the dataset
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.plot() #lineplot by default

# %%
df = iris.drop(['species'],axis=1)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.iloc[0].plot(kind='bar') #first record

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0:5].plot(kind='bar')

# %%
df.iloc[0].plot.bar()

# %%
df1 = sns.load_dataset('titanic')

# %%
df1
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0           0       3    male  22.0  ...   NaN  Southampton     no  False
# 1           1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2           1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3           1       1  female  35.0  ...     C  Southampton    yes  False
# 4           0       3    male  35.0  ...   NaN  Southampton     no   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 886         0       2    male  27.0  ...   NaN  Southampton     no   True
# 887         1       1  female  19.0  ...     B  Southampton    yes   True
# 888         0       3  female   NaN  ...   NaN  Southampton     no  False
# 889         1       1    male  26.0  ...     C    Cherbourg    yes   True
# 890         0       3    male  32.0  ...   NaN   Queenstown     no   True
#
# [891 rows x 15 columns]

# %%
df1.head()
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
df1['pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %%
df1['pclass'].plot(kind='bar')

# %%
df1['pclass'].value_counts().plot(kind='bar')

# %%
df2 = pd.DataFrame(np.random.randn(10,4),columns=['a','b','c','d'])
df2.head()
# Out:
#           a         b         c         d
# 0 -0.910553  0.059514 -1.690282 -2.006652
# 1  0.487184  0.893519  0.978324  0.254672
# 2  2.080583  0.567959  0.329534 -1.155444
# 3  0.183687  0.047078  1.235020 -0.019139
# 4 -1.985182  0.494917 -1.062312  0.574861

# %%
df2.plot.bar()

# %%
df2.plot.line()

# %%
df2.head()
# Out:
#           a         b         c         d
# 0 -0.910553  0.059514 -1.690282 -2.006652
# 1  0.487184  0.893519  0.978324  0.254672
# 2  2.080583  0.567959  0.329534 -1.155444
# 3  0.183687  0.047078  1.235020 -0.019139
# 4 -1.985182  0.494917 -1.062312  0.574861

# %%
df2.plot.barh()  #horizontal bar graph

# %%
iris.plot.hist() #x axis = range, y axis = frequency

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['sepal_length'].hist()

# %%
iris.plot(kind='hist',stacked=True,bins=100)

# %%
iris.plot(kind='hist',stacked=False,bins=100) #bins = no.of.width(samples)

# %%
iris.plot(kind='hist',stacked=True,bins=100,orientation='horizontal')

# %%
iris.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa888f3bc90>,
# ...
#       dtype=object)

# %%
iris.hist(color='r',alpha=0.4) #alpha is transparency of color 0 to 1.
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa888d82950>,
# ...
#       dtype=object)

# %%
iris.hist(color='purple',alpha=0.7) #alpha is transparency of color 0 to 1.
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa888bc21d0>,
# ...
#       dtype=object)

# %%
iris.hist(figsize=(10,10)) #row size and column size
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa888e06f50>,
# ...
#       dtype=object)

# %%
iris.plot.scatter(x='sepal_length',y='sepal_width') #requires x,y axis

# %%
iris.plot.scatter(x='sepal_length',y='petal_length',figsize=(5,5))

# %%
iris.plot.scatter(x='sepal_length',y='petal_length',figsize=(5,5),c='sepal_width') #color thickness based on sepal width

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.plot.scatter(x='sepal_length',y='petal_length',figsize=(5,5),c='sepal_width',s=50)
#s = size, c = color

# %%
iris.plot.hexbin(x='sepal_length',y='petal_length',figsize=(5,5),C='sepal_width',gridsize=10)

# %%
data = iris.iloc[0]

# %%
data = data[0:4]

# %%
data
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: object

# %%
data.plot.pie()

# %%
data1 = df.head(3).iloc[:,0:4].T

# %%
data1
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
data1.plot.pie(subplots=True,figsize=(15,15)) #for each column a pie chart.
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fa8884823d0>,
# ...
#       dtype=object)

# %%
iris.drop('species',axis=1,inplace=True)

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
pd.plotting.scatter_matrix(iris,figsize=(10,10),c='r') #every vs every
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa8883283d0>,
# ...
#       dtype=object)

# %%
pd.plotting.scatter_matrix(iris,figsize=(10,10),c='r',diagonal='kde') #every vs every
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa887e422d0>,
# ...
#       dtype=object)

# %%
iris['sepal_length'].plot(style='r--')  #color and pattern => red and -- dashed

# %%
iris['sepal_length'].plot(style='r--',label='sepal',legend=True)

# %%
iris['sepal_length'].plot(style='r--')

# %%
iris.plot()
